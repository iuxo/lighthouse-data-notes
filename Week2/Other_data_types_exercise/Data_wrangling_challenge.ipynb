# %% [markdown]
# # Data Wrangling Challenge
# ### Pull and manipulate the API data
#
# The point of this exercise is to try data enrichment with data from external APIs. We are going to take data about car crashes in Monroe County, Indiana from 2003 to 2015 and try to figure out the weather during the accident and how many bars there are in the area. We will work with two different APIs during this challenge:
#
# - Foursquare API
# - World Weather Online API
#
# We will try to find correlations between the severity of crash and weather/number of bars in the area. To indicate the severity of a crash, we will use column `Injury Type`.

# %% [markdown]
# ## Data
#
# The data for this exercise can be found [here](https://drive.google.com/file/d/1_KF9oIJV8cB8i3ngA4JPOLWIE_ETE6CJ/view?usp=sharing).
#
# Just run the cells below to get your data ready. Little help from us.

# %%
import pandas as pd
import os
import foursquare
import requests
import json
import pprint as pprint

# %%
data = pd.read_csv("monroe-county-crash-data2003-to-2015.csv", encoding="unicode_escape")
# ========================
# preparing data
data.dropna(subset=['Latitude', 'Longitude'], inplace=True)
# creation of variable with lon and lat together
data['ll'] = data['Latitude'].astype(str) + ',' + data['Longitude'].astype(str)
data = data[data['ll'] != '0.0,0.0']
print(data.shape)
data.head()
# Out:
# (49005, 13)
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
#
#           Injury Type                         Primary Factor  \
# 0   No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                  FOLLOWING TOO CLOSELY
# 2  Non-incapacitating              DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating          FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
#
#        Reported_Location   Latitude  Longitude                        ll
# 0             1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1          2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2  BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3         GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                  W 3RD  39.164848 -86.579625    39.164848,-86.57962482

# %% [markdown]
# # Foursquare API
#
# Foursquare API documentation is [here](https://developer.foursquare.com/)
#
# 1. Start a foursquare application and get your keys.
# 2. For each crash, create the function **get_venues** that will pull bars in the radius of 5km around the crash
#
# #### example
# `get_venues('48.146394, 17.107969')`
#
# 3. Find a relationship (if there is any) between number of bars in the area and severity of the crash.
#
# HINTs:
# - check out python package "foursquare" (no need to send HTTP requests directly with library `requests`)
# - **categoryId** for bars and nightlife needs to be found in the [foursquare API documentation](https://developer.foursquare.com/docs/api-reference/venues/search/)

# %%
FOURSQUARE_KEY = os.environ["FOURSQUARE_API"]

url = "https://api.foursquare.com/v3/places/search"

# Create dictionary for headers
headers = {"Accept": "application/json"}
# Add key with our API KEY
headers['Authorization'] = FOURSQUARE_KEY

# %%
def get_venues(lat, long):
    res = requests.get(url = url, params ={'query': 'bar', 'll': str(lat) + ',' + str(long), 'radius': 5000}, headers=headers)
    fdata = res.json()
    with open('bars_within_5km.json','a') as f:
        json.dump(fdata, f)
        f.write(f'\n')
    pprint.pprint(fdata)

# %%
get_venues(data['Latitude'][0], data['Longitude'][0])
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 39.15920668,
#                                                   'longitude': -86.52587356},
#                                        'radius': 5000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#                                        'suffix': '.png'},
#                               'id': 13026,
#                               'name': 'BBQ Joint'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#                                        'suffix': '.png'},
#                               'id': 13303,
#                               'name': 'Mexican Restaurant'}],
#               'chains': [],
#               'distance': 1153,
#               'fsq_id': '4aebd299f964a520e3c421e3',
#               'geocodes': {'main': {'latitude': 39.166716,
#                                     'longitude': -86.535315},
#                            'roof': {'latitude': 39.166716,
#                                     'longitude': -86.535315}},
#               'link': '/v3/places/4aebd299f964a520e3c421e3',
#               'location': {'address': '210 W Kirkwood Ave',
#                            'census_block': '181050001001011',
#                            'country': 'US',
#                            'cross_street': 'at College Ave',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '210 W Kirkwood Ave (at '
#                                                 'College Ave), Bloomington, IN '
#                                                 '47404',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Arlington'],
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'The Alley Bar',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#                                        'suffix': '.png'},
#                               'id': 13022,
#                               'name': 'Sports Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#                                        'suffix': '.png'},
#                               'id': 13026,
#                               'name': 'BBQ Joint'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#                                        'suffix': '.png'},
#                               'id': 13031,
#                               'name': 'Burger Joint'}],
#               'chains': [],
#               'distance': 1215,
#               'fsq_id': '4b074185f964a520ccfa22e3',
#               'geocodes': {'main': {'latitude': 39.168007,
#                                     'longitude': -86.533749},
#                            'roof': {'latitude': 39.168007,
#                                     'longitude': -86.533749}},
#               'link': '/v3/places/4b074185f964a520ccfa22e3',
#               'location': {'address': '215 N Walnut St',
#                            'census_block': '181050001001013',
#                            'country': 'US',
#                            'cross_street': 'at W 7th St',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '215 N Walnut St (at W 7th '
#                                                 'St), Bloomington, IN 47404',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Arlington'],
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'Brothers Bar & Grill',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'chains': [],
#               'distance': 1151,
#               'fsq_id': '507c2800e4b0b5e9215c9444',
#               'geocodes': {'main': {'latitude': 39.166841,
#                                     'longitude': -86.535183},
#                            'roof': {'latitude': 39.166841,
#                                     'longitude': -86.535183}},
#               'link': '/v3/places/507c2800e4b0b5e9215c9444',
#               'location': {'address': '101 N College Ave',
#                            'census_block': '181050001001011',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '101 N College Ave, '
#                                                 'Bloomington, IN 47404',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Arlington'],
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'The Tap',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'chains': [],
#               'distance': 867,
#               'fsq_id': '4aef51e6f964a52086d721e3',
#               'geocodes': {'main': {'latitude': 39.166781,
#                                     'longitude': -86.528602},
#                            'roof': {'latitude': 39.166781,
#                                     'longitude': -86.528602}},
#               'link': '/v3/places/4aef51e6f964a52086d721e3',
#               'location': {'address': '423 E Kirkwood Ave',
#                            'census_block': '181050001003006',
#                            'country': 'US',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '423 E Kirkwood Ave, '
#                                                 'Bloomington, IN 47408',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Marlin Hills'],
#                            'postcode': '47408',
#                            'region': 'IN'},
#               'name': "Nick's English Hut",
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'}],
#               'chains': [],
#               'distance': 2571,
#               'fsq_id': '4b9adfc8f964a52065de35e3',
#               'geocodes': {'main': {'latitude': 39.154575,
#                                     'longitude': -86.496632},
#                            'roof': {'latitude': 39.154575,
#                                     'longitude': -86.496632}},
#               'link': '/v3/places/4b9adfc8f964a52065de35e3',
#               'location': {'address': '1131 S College Mall Rd',
#                            'census_block': '181050009042007',
#                            'country': 'US',
#                            'cross_street': 'at Covenanter Dr',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '1131 S College Mall Rd (at '
#                                                 'Covenanter Dr), Bloomington, '
#                                                 'IN 47401',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Hoosier Acres'],
#                            'postcode': '47401',
#                            'region': 'IN'},
#               'name': '56 Degrees Bar',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#                                        'suffix': '.png'},
#                               'id': 12082,
#                               'name': 'Organization'}],
#               'chains': [{'id': '16cc6490-992b-0132-fd75-7a163eb2a6fc',
#                           'name': 'American Legion'}],
#               'distance': 2805,
#               'fsq_id': '4c0addff009a0f47f038eabf',
#               'geocodes': {'main': {'latitude': 39.165765,
#                                     'longitude': -86.557396},
#                            'roof': {'latitude': 39.165765,
#                                     'longitude': -86.557396}},
#               'link': '/v3/places/4c0addff009a0f47f038eabf',
#               'location': {'address': '1800 W 3rd St',
#                            'census_block': '181050006011023',
#                            'country': 'US',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '1800 W 3rd St, Bloomington, '
#                                                 'IN 47404',
#                            'locality': 'Bloomington',
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'American Legion',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#                                        'suffix': '.png'},
#                               'id': 10039,
#                               'name': 'Music Venue'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'}],
#               'chains': [],
#               'distance': 980,
#               'fsq_id': '4b270d10f964a5206d8424e3',
#               'geocodes': {'main': {'latitude': 39.165806,
#                                     'longitude': -86.533333},
#                            'roof': {'latitude': 39.165806,
#                                     'longitude': -86.533333}},
#               'link': '/v3/places/4b270d10f964a5206d8424e3',
#               'location': {'address': '123 S Walnut St',
#                            'census_block': '181050001003012',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '123 S Walnut St, Bloomington, '
#                                                 'IN 47404',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Marlin Hills'],
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'The Bishop',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#                                        'suffix': '.png'},
#                               'id': 13009,
#                               'name': 'Cocktail Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'chains': [],
#               'distance': 995,
#               'fsq_id': '4bfe9dc7cdfbef3b6f52323e',
#               'geocodes': {'main': {'latitude': 39.166311,
#                                     'longitude': -86.533097}},
#               'link': '/v3/places/4bfe9dc7cdfbef3b6f52323e',
#               'location': {'address': '108 E Kirkwood Ave',
#                            'census_block': '181050001003012',
#                            'country': 'US',
#                            'cross_street': 'at Walnut',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '108 E Kirkwood Ave (at '
#                                                 'Walnut), Bloomington, IN '
#                                                 '47408',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Marlin Hills'],
#                            'postcode': '47408',
#                            'region': 'IN'},
#               'name': 'The Root Cellar Lounge',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#                                        'suffix': '.png'},
#                               'id': 13022,
#                               'name': 'Sports Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'chains': [],
#               'distance': 1297,
#               'fsq_id': '4b1958c4f964a520a4db23e3',
#               'geocodes': {'main': {'latitude': 39.169072,
#                                     'longitude': -86.533818},
#                            'roof': {'latitude': 39.169072,
#                                     'longitude': -86.533818}},
#               'link': '/v3/places/4b1958c4f964a520a4db23e3',
#               'location': {'address': '319 N Walnut St',
#                            'census_block': '181050001004022',
#                            'country': 'US',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '319 N Walnut St, Bloomington, '
#                                                 'IN 47404',
#                            'locality': 'Bloomington',
#                            'neighborhood': ['Arlington'],
#                            'postcode': '47404',
#                            'region': 'IN'},
#               'name': 'Kilroys Sports',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'}],
#               'chains': [],
#               'distance': 4362,
#               'fsq_id': '522293d111d20e5a982b5064',
#               'geocodes': {'main': {'latitude': 39.127396,
#                                     'longitude': -86.555422},
#                            'roof': {'latitude': 39.127396,
#                                     'longitude': -86.555422}},
#               'link': '/v3/places/522293d111d20e5a982b5064',
#               'location': {'address': '3342 S Dawson Ln',
#                            'census_block': '181050011023024',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Indianapolis',
#                            'formatted_address': '3342 S Dawson Ln, '
#                                                 'Bloomington, IN 47403',
#                            'locality': 'Bloomington',
#                            'postcode': '47403',
#                            'region': 'IN'},
#               'name': 'The Moontower Bar and Grill',
#               'related_places': {},
#               'timezone': 'America/Indiana/Indianapolis'}]}

# %% [markdown]
# # World Weather Online API
#
# World Weather Online API is [here](https://www.worldweatheronline.com/developer/api/historical-weather-api.aspx)
#
# 1. Sign up for FREE api key if you haven't done that before (it's free for **30 days**).
# 2. For each crush, get the weather for the location and date.
# 3. Find a relationship between the weather and severity of the crash.
#
# Hints:
#
# * pull weather only for smaller sample of crashes (250 or so) due to API limits
# * for sending HTTP requests check out "requests" library [here](http://docs.python-requests.org/en/master/)

# %%
import requests
import time
api_key = os.environ["<>"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6996/1001521114.py in <cell line: 3>()
#       1 import requests
#       2 import time
# ----> 3 api_key = os.environ["<>"]
#
# c:\Users\jared\anaconda3\envs\THE_ONE\lib\os.py in __getitem__(self, key)
#     673         except KeyError:
#     674             # raise KeyError with the original key value
# --> 675             raise KeyError(key) from None
#     676         return self.decodevalue(value)
#     677
#
# KeyError: '<>'
