# %% [markdown]
# ## Advanced tuning of parameters
#
# In this tutorial, we will apply the skills from previous tutorials and build a classifier using the `Pipelines` and `FeatureUnion` functions from sklearn.

# %%
# IMPORT PACKAGES
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data
#
# We will be building a binary classifier that predicts wheter a person has diabetes or not, using information on the patient's health.
#
# The data can be found [here](https://drive.google.com/file/d/1TvCKlmH3Z32XAKk-VUcZyYu95Ccyw3PO/view?usp=sharing).

# %%
col_names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
feature_names = col_names[:-1]
target_name = col_names[-1]
data = pd.read_csv('pima-indians-diabetes.csv', sep=';')
data.head(3)
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1

# %%
X = data[feature_names]
y = data[target_name]

# %% [markdown]
# ### Task
#
# Build classifier which predicts the target variable `class` using rest of the attributes. The model should be fitted using pipeline that contains:
# - PCA method
# - SelectKBest method
# - FeatureUnion
# - Random Forest
#
# Choose the best set of parameters using `Pipeline` and grid_search.
#
# > #### Note
# > **In this exercise, we are focusing on the implementation of pipeline. Since we have only 9 columns in our dataset the PCA is probably not the best technique to use during the data preparation from a methodology point of view.**

# %%
pca = PCA(n_components=2)

selection = SelectKBest(k=3)

combined_features = FeatureUnion([('pca', pca), ('univ_select', selection)])

clf = RandomForestClassifier()
clf.fit(X,y)
y_pred = clf.predict(X)

accuracy_score(y, y_pred)
# Out:
# 1.0

# %%
pipeline = Pipeline([('features', combined_features), ('rand_forest', clf)])

params = {'features__pca__n_components': [1, 2, 3],
            'features__univ_select__k': [1, 2, 3],
            'rand_forest__max_depth': [1, 2, 3],
            'rand_forest__min_samples_split': [2, 3, 4],
            'rand_forest__min_samples_leaf': [1, 2, 3]
}

# create gridsearch object
grid = GridSearchCV(pipeline, params, verbose=10, refit=True)

# fit the model and tune params
grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5; 1/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 1/5; 1/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 2/5; 1/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 2/5; 1/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 3/5; 1/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 3/5; 1/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.760 total time=   0.0s
# [CV 4/5; 1/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 4/5; 1/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.752 total time=   0.0s
# [CV 5/5; 1/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 5/5; 1/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 1/5; 2/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 1/5; 2/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 2/5; 2/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 2/5; 2/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.727 total time=   0.0s
# [CV 3/5; 2/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 3/5; 2/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 4/5; 2/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 4/5; 2/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 2/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 5/5; 2/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 1/5; 3/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 1/5; 3/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 2/5; 3/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 2/5; 3/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.721 total time=   0.0s
# [CV 3/5; 3/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 3/5; 3/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.760 total time=   0.0s
# [CV 4/5; 3/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 4/5; 3/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 5/5; 3/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 5/5; 3/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# [CV 1/5; 4/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 1/5; 4/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.695 total time=   0.0s
# [CV 2/5; 4/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 2/5; 4/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.721 total time=   0.0s
# [CV 3/5; 4/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 3/5; 4/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.753 total time=   0.0s
# [CV 4/5; 4/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 4/5; 4/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.752 total time=   0.0s
# [CV 5/5; 4/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 5/5; 4/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.732 total time=   0.0s
# [CV 1/5; 5/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 1/5; 5/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 2/5; 5/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 2/5; 5/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.721 total time=   0.0s
# [CV 3/5; 5/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 3/5; 5/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 4/5; 5/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 4/5; 5/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 5/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 5/5; 5/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.739 total time=   0.0s
# [CV 1/5; 6/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 1/5; 6/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.708 total time=   0.0s
# [CV 2/5; 6/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 2/5; 6/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 3/5; 6/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 3/5; 6/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.688 total time=   0.0s
# [CV 4/5; 6/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 4/5; 6/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 5/5; 6/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 5/5; 6/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.739 total time=   0.0s
# [CV 1/5; 7/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 1/5; 7/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 2/5; 7/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 2/5; 7/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.721 total time=   0.0s
# [CV 3/5; 7/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 3/5; 7/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.766 total time=   0.0s
# [CV 4/5; 7/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 4/5; 7/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.739 total time=   0.0s
# [CV 5/5; 7/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 5/5; 7/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.739 total time=   0.0s
# [CV 1/5; 8/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 1/5; 8/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 2/5; 8/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 2/5; 8/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.714 total time=   0.0s
# [CV 3/5; 8/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 3/5; 8/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.766 total time=   0.0s
# [CV 4/5; 8/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 4/5; 8/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 8/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 5/5; 8/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.732 total time=   0.0s
# [CV 1/5; 9/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 1/5; 9/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.708 total time=   0.0s
# [CV 2/5; 9/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 2/5; 9/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 3/5; 9/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 3/5; 9/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.760 total time=   0.0s
# [CV 4/5; 9/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 4/5; 9/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.732 total time=   0.0s
# [CV 5/5; 9/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 5/5; 9/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=1, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# [CV 1/5; 10/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 1/5; 10/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.701 total time=   0.0s
# [CV 2/5; 10/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 2/5; 10/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.721 total time=   0.0s
# [CV 3/5; 10/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 3/5; 10/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.714 total time=   0.0s
# [CV 4/5; 10/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 4/5; 10/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.752 total time=   0.0s
# [CV 5/5; 10/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 5/5; 10/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 1/5; 11/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 1/5; 11/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 2/5; 11/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 2/5; 11/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 3/5; 11/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 3/5; 11/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.734 total time=   0.0s
# [CV 4/5; 11/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 4/5; 11/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 11/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 5/5; 11/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.745 total time=   0.0s
# [CV 1/5; 12/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 1/5; 12/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 2/5; 12/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 2/5; 12/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 3/5; 12/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 3/5; 12/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.766 total time=   0.0s
# [CV 4/5; 12/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 4/5; 12/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 5/5; 12/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 5/5; 12/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# [CV 1/5; 13/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 1/5; 13/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 2/5; 13/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 2/5; 13/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.701 total time=   0.0s
# [CV 3/5; 13/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 3/5; 13/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.766 total time=   0.0s
# [CV 4/5; 13/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 4/5; 13/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 5/5; 13/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 5/5; 13/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 1/5; 14/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 1/5; 14/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 2/5; 14/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 2/5; 14/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 3/5; 14/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 3/5; 14/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.760 total time=   0.0s
# [CV 4/5; 14/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 4/5; 14/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 14/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 5/5; 14/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 1/5; 15/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 1/5; 15/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 2/5; 15/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 2/5; 15/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 3/5; 15/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 3/5; 15/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 4/5; 15/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 4/5; 15/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.758 total time=   0.0s
# [CV 5/5; 15/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 5/5; 15/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# [CV 1/5; 16/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 1/5; 16/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.701 total time=   0.0s
# [CV 2/5; 16/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 2/5; 16/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 3/5; 16/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 3/5; 16/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.714 total time=   0.0s
# [CV 4/5; 16/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 4/5; 16/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.739 total time=   0.0s
# [CV 5/5; 16/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 5/5; 16/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.752 total time=   0.0s
# [CV 1/5; 17/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 1/5; 17/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 2/5; 17/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 2/5; 17/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 3/5; 17/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 3/5; 17/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 4/5; 17/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 4/5; 17/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 17/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 5/5; 17/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.745 total time=   0.0s
# [CV 1/5; 18/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 1/5; 18/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.708 total time=   0.0s
# [CV 2/5; 18/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 2/5; 18/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.714 total time=   0.0s
# [CV 3/5; 18/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 3/5; 18/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.753 total time=   0.0s
# [CV 4/5; 18/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 4/5; 18/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.758 total time=   0.0s
# [CV 5/5; 18/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 5/5; 18/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=2, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# [CV 1/5; 19/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 1/5; 19/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.695 total time=   0.0s
# [CV 2/5; 19/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 2/5; 19/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 3/5; 19/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 3/5; 19/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.747 total time=   0.0s
# [CV 4/5; 19/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 4/5; 19/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.739 total time=   0.0s
# [CV 5/5; 19/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2
# [CV 5/5; 19/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=2;, score=0.758 total time=   0.0s
# [CV 1/5; 20/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 1/5; 20/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 2/5; 20/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 2/5; 20/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.701 total time=   0.0s
# [CV 3/5; 20/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 3/5; 20/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.747 total time=   0.0s
# [CV 4/5; 20/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 4/5; 20/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.739 total time=   0.0s
# [CV 5/5; 20/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 5/5; 20/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 1/5; 21/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 1/5; 21/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 2/5; 21/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 2/5; 21/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 3/5; 21/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 3/5; 21/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.721 total time=   0.0s
# [CV 4/5; 21/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 4/5; 21/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.765 total time=   0.0s
# [CV 5/5; 21/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 5/5; 21/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.765 total time=   0.0s
# [CV 1/5; 22/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 1/5; 22/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 2/5; 22/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 2/5; 22/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.701 total time=   0.0s
# [CV 3/5; 22/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 3/5; 22/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.727 total time=   0.0s
# [CV 4/5; 22/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 4/5; 22/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.752 total time=   0.0s
# [CV 5/5; 22/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 5/5; 22/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 1/5; 23/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 1/5; 23/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 2/5; 23/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 2/5; 23/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.714 total time=   0.0s
# [CV 3/5; 23/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 3/5; 23/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.747 total time=   0.0s
# [CV 4/5; 23/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 4/5; 23/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.752 total time=   0.0s
# [CV 5/5; 23/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 5/5; 23/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.765 total time=   0.0s
# [CV 1/5; 24/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 1/5; 24/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 2/5; 24/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 2/5; 24/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.701 total time=   0.0s
# [CV 3/5; 24/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 3/5; 24/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.740 total time=   0.0s
# [CV 4/5; 24/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 4/5; 24/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.758 total time=   0.0s
# [CV 5/5; 24/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 5/5; 24/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 1/5; 25/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 1/5; 25/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 2/5; 25/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 2/5; 25/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.701 total time=   0.0s
# [CV 3/5; 25/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 3/5; 25/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.734 total time=   0.0s
# [CV 4/5; 25/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 4/5; 25/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 5/5; 25/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 5/5; 25/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.758 total time=   0.0s
# [CV 1/5; 26/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 1/5; 26/243] END features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.708 total time=   0.0s
# [CV 2/5; 26/243] START features__pca__n_components=1, features__univ_select__k=1, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# ...
# [CV 1/5; 236/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 2/5; 236/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 2/5; 236/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.721 total time=   0.0s
# [CV 3/5; 236/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 3/5; 236/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 4/5; 236/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 4/5; 236/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.804 total time=   0.0s
# [CV 5/5; 236/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3
# [CV 5/5; 236/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=3;, score=0.745 total time=   0.0s
# [CV 1/5; 237/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 1/5; 237/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.753 total time=   0.0s
# [CV 2/5; 237/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 2/5; 237/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.721 total time=   0.0s
# [CV 3/5; 237/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 3/5; 237/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.747 total time=   0.0s
# [CV 4/5; 237/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 4/5; 237/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.791 total time=   0.0s
# [CV 5/5; 237/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4
# [CV 5/5; 237/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=1, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 1/5; 238/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 1/5; 238/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.740 total time=   0.0s
# [CV 2/5; 238/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 2/5; 238/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.708 total time=   0.0s
# [CV 3/5; 238/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 3/5; 238/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.747 total time=   0.0s
# [CV 4/5; 238/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 4/5; 238/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.810 total time=   0.0s
# [CV 5/5; 238/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2
# [CV 5/5; 238/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=2;, score=0.745 total time=   0.0s
# [CV 1/5; 239/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 1/5; 239/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.747 total time=   0.0s
# [CV 2/5; 239/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 2/5; 239/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.714 total time=   0.0s
# [CV 3/5; 239/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 3/5; 239/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.753 total time=   0.0s
# [CV 4/5; 239/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 4/5; 239/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.797 total time=   0.0s
# [CV 5/5; 239/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3
# [CV 5/5; 239/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=3;, score=0.771 total time=   0.0s
# [CV 1/5; 240/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 1/5; 240/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.753 total time=   0.0s
# [CV 2/5; 240/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 2/5; 240/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.708 total time=   0.0s
# [CV 3/5; 240/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 3/5; 240/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.740 total time=   0.0s
# [CV 4/5; 240/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 4/5; 240/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.804 total time=   0.0s
# [CV 5/5; 240/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4
# [CV 5/5; 240/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=2, rand_forest__min_samples_split=4;, score=0.752 total time=   0.0s
# [CV 1/5; 241/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 1/5; 241/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.753 total time=   0.0s
# [CV 2/5; 241/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 2/5; 241/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.721 total time=   0.0s
# [CV 3/5; 241/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 3/5; 241/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.740 total time=   0.1s
# [CV 4/5; 241/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 4/5; 241/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.804 total time=   0.0s
# [CV 5/5; 241/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2
# [CV 5/5; 241/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=2;, score=0.765 total time=   0.0s
# [CV 1/5; 242/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 1/5; 242/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.740 total time=   0.0s
# [CV 2/5; 242/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 2/5; 242/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.734 total time=   0.0s
# [CV 3/5; 242/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 3/5; 242/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.740 total time=   0.0s
# [CV 4/5; 242/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 4/5; 242/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.804 total time=   0.0s
# [CV 5/5; 242/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3
# [CV 5/5; 242/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=3;, score=0.765 total time=   0.0s
# [CV 1/5; 243/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 1/5; 243/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.760 total time=   0.0s
# [CV 2/5; 243/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 2/5; 243/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.727 total time=   0.0s
# [CV 3/5; 243/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 3/5; 243/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.747 total time=   0.0s
# [CV 4/5; 243/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 4/5; 243/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.797 total time=   0.0s
# [CV 5/5; 243/243] START features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4
# [CV 5/5; 243/243] END features__pca__n_components=3, features__univ_select__k=3, rand_forest__max_depth=3, rand_forest__min_samples_leaf=3, rand_forest__min_samples_split=4;, score=0.745 total time=   0.0s
# GridSearchCV(estimator=Pipeline(steps=[('features',
#                                         FeatureUnion(transformer_list=[('pca',
#                                                                         PCA(n_components=2)),
#                                                                        ('univ_select',
#                                                                         SelectKBest(k=3))])),
#                                        ('rand_forest',
#                                         RandomForestClassifier())]),
#              param_grid={'features__pca__n_components': [1, 2, 3],
#                          'features__univ_select__k': [1, 2, 3],
#                          'rand_forest__max_depth': [1, 2, 3],
#                          'rand_forest__min_samples_leaf': [1, 2, 3],
#                          'rand_forest__min_samples_split': [2, 3, 4]},
#              verbose=10)

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'features__pca__n_components': 2, 'features__univ_select__k': 3, 'rand_forest__max_depth': 3, 'rand_forest__min_samples_leaf': 1, 'rand_forest__min_samples_split': 4}
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('pca', PCA(n_components=2)),
#                                                 ('univ_select',
#                                                  SelectKBest(k=3))])),
#                 ('rand_forest',
#                  RandomForestClassifier(max_depth=3, min_samples_split=4))])

# %%
print(grid.best_score_)
# Out:
# 0.7656735421441304
