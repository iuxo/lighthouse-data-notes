# %% [markdown]
# ## Density Models Assignment

# %%
# import matplotlib
import matplotlib.pyplot as plt

# set figure size
plt.rcParams["figure.figsize"] = (12,8)

#import numpy
import numpy as np

# from sklearn import make_blobs
from sklearn.datasets import make_blobs

# import DBSCAN
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Task: Generate clusters with make_blobs function
#
# Use the following settings:
#    * n_samples=150,
#    * n_features=2,
#    * centers=3,
#    * cluster_std=0.6,
#    * random_state=0

# %%
X, y = make_blobs(n_samples = 150,
                  n_features = 2,
                  centers = 3,
                  cluster_std = 0.6,
                  random_state = 0)

# %% [markdown]
# * plot data points

# %%
plt.scatter(X[:,0],
            X[:,1],
            c='black',
            marker='o')

# %% [markdown]
# * define function plot_clusters

# %%
def plot_clusters(X, y_res, plt_cluster_centers = False):
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster, 0]
        y = X[y_res == cluster, 1]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x, y, s = 50, marker= 's', label = f'cluster {cluster}')
        
    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker = '*',
                    c = 'red',
                    s = 250,
                    label = 'centroids')
    
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ## Objective:
# Try to find optimal settings of `eps` and `min_samples` params of DBSCAN. You can iterate over multiple parameters combinations and plot the clustering results.

# %% [markdown]
# * define params space: two lists with `eps` and `min_samples` respectively

# %%
eps = [0.25, 0.5, 0.75, 1]
min_samples = [4, 5, 6, 8, 10]

# %% [markdown]
# * combinations (hint: use 'product' function from 'itertools')

# %%
import itertools

# import DBSCAN
from sklearn.cluster import DBSCAN

combination = list(itertools.product(eps, min_samples))
print(combination)
# Out:
# [(0.25, 4), (0.25, 5), (0.25, 6), (0.25, 8), (0.25, 10), (0.5, 4), (0.5, 5), (0.5, 6), (0.5, 8), (0.5, 10), (0.75, 4), (0.75, 5), (0.75, 6), (0.75, 8), (0.75, 10), (1, 4), (1, 5), (1, 6), (1, 8), (1, 10)]

# %% [markdown]
# - fit DBSCAN for each combinations and plot the results

# %%
for item in combination:
    db = DBSCAN(eps = item[0], min_samples = item[1], metric = 'euclidean')
    y_db = db.fit_predict(X)
    plot_clusters(X, y_db, plt_cluster_centers=True)
    print(item)
# Out:
# (0.25, 4)
# (0.25, 5)
# (0.25, 6)
# (0.25, 8)
# (0.25, 10)
# (0.5, 4)
# (0.5, 5)
# (0.5, 6)
# (0.5, 8)
# (0.5, 10)
# (0.75, 4)
# (0.75, 5)
# (0.75, 6)
# (0.75, 8)
# (0.75, 10)
# (1, 4)
# (1, 5)
# (1, 6)
# (1, 8)
# (1, 10)
