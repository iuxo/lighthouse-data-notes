# %%
# import geopandas and matplotlib
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# countries data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# **Print the top 5 rows of world dataframe.**

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.columns
# Out:
# Index(['pop_est', 'continent', 'name', 'iso_a3', 'gdp_md_est', 'geometry'], dtype='object')

# %% [markdown]
# **Remove continents which have only one country in dataframe.**

# %%
# continents with only one country
world.groupby(by='continent').count()
# Out:
#                          pop_est  name  iso_a3  gdp_md_est  geometry
# continent
# Africa                        51    51      51          51        51
# Antarctica                     1     1       1           1         1
# Asia                          47    47      47          47        47
# Europe                        39    39      39          39        39
# North America                 18    18      18          18        18
# Oceania                        7     7       7           7         7
# Seven seas (open ocean)        1     1       1           1         1
# South America                 13    13      13          13        13

# %%
# remove these continents
world = world[(world.name != "Antarctica")]

# %% [markdown]
# **Create dataframe with top 3 most populated countries from each continent and store the result in dataframe with name 'world_filtered'.**

# %%
world_filtered = world.sort_values(by = ['continent', 'pop_est'], ascending = [True, False]).groupby(['continent'], sort=True).head(3)

# %% [markdown]
# **Print the 'world_filtered' dataframe.**

# %%
world_filtered
# Out:
#         pop_est                continent                      name iso_a3  \
# 56    190632261                   Africa                   Nigeria    NGA
# 165   105350020                   Africa                  Ethiopia    ETH
# 163    97041072                   Africa                     Egypt    EGY
# 139  1379302771                     Asia                     China    CHN
# 98   1281935911                     Asia                     India    IND
# 8     260580739                     Asia                 Indonesia    IDN
# 18    142257519                   Europe                    Russia    RUS
# 121    80594017                   Europe                   Germany    DEU
# 43     67106161                   Europe                    France    -99
# 4     326625791            North America  United States of America    USA
# 27    124574795            North America                    Mexico    MEX
# 3      35623680            North America                    Canada    CAN
# 137    23232413                  Oceania                 Australia    AUS
# 7       6909701                  Oceania          Papua New Guinea    PNG
# 136     4510327                  Oceania               New Zealand    NZL
# 23          140  Seven seas (open ocean)    Fr. S. Antarctic Lands    ATF
# 29    207353391            South America                    Brazil    BRA
# 32     47698524            South America                  Colombia    COL
# 9      44293293            South America                 Argentina    ARG
#
#      gdp_md_est                                           geometry
# 56    1089000.0  POLYGON ((2.692 6.259, 2.749 7.871, 2.724 8.50...
# 165    174700.0  POLYGON ((47.789 8.003, 44.964 5.002, 43.661 4...
# 163   1105000.0  POLYGON ((36.866 22.000, 32.900 22.000, 29.020...
# 139  21140000.0  MULTIPOLYGON (((109.475 18.198, 108.655 18.508...
# 98    8721000.0  POLYGON ((97.327 28.262, 97.403 27.883, 97.052...
# 8     3028000.0  MULTIPOLYGON (((141.000 -2.600, 141.017 -5.859...
# 18    3745000.0  MULTIPOLYGON (((178.725 71.099, 180.000 71.516...
# 121   3979000.0  POLYGON ((14.120 53.757, 14.353 53.248, 14.075...
# 43    2699000.0  MULTIPOLYGON (((-51.658 4.156, -52.249 3.241, ...
# 4    18560000.0  MULTIPOLYGON (((-122.840 49.000, -120.000 49.0...
# 27    2307000.0  POLYGON ((-117.128 32.535, -115.991 32.612, -1...
# 3     1674000.0  MULTIPOLYGON (((-122.840 49.000, -122.974 49.0...
# 137   1189000.0  MULTIPOLYGON (((147.689 -40.808, 148.289 -40.8...
# 7       28020.0  MULTIPOLYGON (((141.000 -2.600, 142.735 -3.289...
# 136    174800.0  MULTIPOLYGON (((176.886 -40.066, 176.508 -40.6...
# 23         16.0  POLYGON ((68.935 -48.625, 69.580 -48.940, 70.5...
# 29    3081000.0  POLYGON ((-53.374 -33.768, -53.651 -33.202, -5...
# 32     688000.0  POLYGON ((-66.876 1.253, -67.065 1.130, -67.26...
# 9      879400.0  MULTIPOLYGON (((-68.634 -52.636, -68.250 -53.1...

# %% [markdown]
# -----------------
# ## Part I: Create a choropleth map of world:
#
#    - First using **Geopandas**
#        - Note: Geopandas may not work well on your computers, especially on Windows computers, it is advised to use Google Collab for this assignment.
#    - Second using **Plotly**
#        - Note: Plotly may not work well on Jupyter Labs, it is advised to use Jupyter Notebooks or Google Collab for the plotly portion.
#
#
# > #### Notes
# > * the colors of countries from 'world_filtered' are based on population
# > * other countries can stay white

# %% [markdown]
# ### GeoPandas

# %%
# create figure and axes

fig, ax = plt.subplots(figsize = (15,12))

# create map from world_filtered data-frame

world_filtered.plot(column = 'pop_est', ax = ax, legend = True,
                    legend_kwds={'label': "Population by Country",
                    'orientation': 'horizontal'})

# add the rest of the countries

remaining_world_mask = ~world.isin(world_filtered).all(axis='columns')

remaining_world = world[remaining_world_mask]

remaining_world.plot(column = 'pop_est', ax = ax, legend = True,
                    legend_kwds={'orientation': 'horizontal'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plotly

# %% [markdown]
# -----------
# ## Part II: More Geopandas
#
# In Geopandas:
#
# * add New York, Berlin, Paris, Toronto, Calgary, Tokyo to the map you have created before
#     * to get geometry of these cities use the function, **gpd.tools.geocode**(['New York', 'Berlin', 'Paris','Toronto', 'Calgary', 'Tokyo'])
#     * if you do not have the geopy library instaled, install it with the following command **in the jupyter notebook cell** `!pip install geopy`

# %%
# get geometry


# create figure and axes




# create map from world_filtered data-frame




# add the rest of the countries



# add cities
